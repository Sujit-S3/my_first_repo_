# %% [markdown]
# What is the difference between hardware and software? Give one example of each.
#
#
# answer:
#      Hardware refers to the physical components of a computer system, things you can touch. For example, a computer mouse. Software, on the other hand, is a set of instructions, data, or programs used to operate computers and execute specific tasks. An example of software is a web browser like Chrome or Firefox.
